# %%
import h5py
filename = "2017_2019_images_pv_processed.hdf5"
f = h5py.File(filename, 'r')

# %%
list(f.keys())
# Out:
# ['test', 'trainval']

# %%
dset = f['trainval']
list(dset.items())
# Out:
# [('images_log',
#   <HDF5 dataset "images_log": shape (349372, 64, 64, 3), type "|u1">),
#  ('pv_log', <HDF5 dataset "pv_log": shape (349372,), type "<f8">)]

# %%
import numpy as np
import pandas as pd

train_imarr = np.array(dset['images_log'])
train_pvlog = np.array(dset['pv_log'])
test_imarr = np.array(dset['images_log'])
test_pvlog = np.array(dset['pv_log'])

# %%
import matplotlib.pyplot as plt

imgplot = plt.imshow(train_imarr[2000])
print(train_pvlog[2000])
# Out:
# 23.277677710000003

# %%
plt.imshow(train_imarr.mean(axis=0)/255)

# %%
plt.hist(train_pvlog)
train_pvlog.max()
# Out:
# 29.58536961

# %%
plt.figure(figsize=(30,9))
for i in range(0,30):
    plt.subplot(3,10,i+1)
    plt.imshow(train_imarr[(train_pvlog>i) & (train_pvlog<(i+1))].mean(0)/255)
    plt.title(F'mean of {i} < pvlog < {(i+1)}')

# %%
plt.boxplot(train_pvlog)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5ee7b1b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5ee7b2050>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5ee7b1870>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5ee7b2590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5ee7b2830>],
#  'means': []}
